# %%
import pandas as pd
data=pd.read_excel("Sample - Superstore.xls")
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
data.shape
# Out:
# (9994, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
data.isna().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
data.columns=data.columns.str.lower().str.replace(' ','_').str.replace('-','_')

# %%
data.tail(20)
# Out:
#       row_id        order_id order_date  ship_date       ship_mode  \
# 9974    9975  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 9975    9976  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 9976    9977  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 9977    9978  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 9978    9979  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 9979    9980  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 9980    9981  US-2015-151435 2015-09-06 2015-09-09    Second Class
# 9981    9982  CA-2017-163566 2017-08-03 2017-08-06     First Class
# 9982    9983  US-2016-157728 2016-09-22 2016-09-28  Standard Class
# 9983    9984  US-2016-157728 2016-09-22 2016-09-28  Standard Class
# 9984    9985  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9985    9986  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9986    9987  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# ...

# %% [markdown]
# ### 1.1 Feature enginnering:

# %%
df=data.copy()

# %%
def new_columns(df, cols):
    for col in cols:
        df = df.assign(**{
            f'{col}_year': lambda x: x[col].dt.year,
            f'{col}_month': lambda x: x[col].dt.month,
            f'{col}_day': lambda x: x[col].dt.day,
        })
    return df

# %%
cols=['order_date','ship_date']
new_df=new_columns(df,cols).drop(cols, axis=1)

# %%
new_df.shape
# Out:
# (9994, 25)

# %%
new_df.duplicated().sum()
# Out:
# 0

# %%
new_df.tail(20)
# Out:
#       row_id        order_id       ship_mode customer_id     customer_name  \
# 9974    9975  US-2016-103674  Standard Class    AP-10720        Anne Pryor
# 9975    9976  US-2016-103674  Standard Class    AP-10720        Anne Pryor
# 9976    9977  US-2016-103674  Standard Class    AP-10720        Anne Pryor
# 9977    9978  US-2016-103674  Standard Class    AP-10720        Anne Pryor
# 9978    9979  US-2016-103674  Standard Class    AP-10720        Anne Pryor
# 9979    9980  US-2016-103674  Standard Class    AP-10720        Anne Pryor
# 9980    9981  US-2015-151435    Second Class    SW-20455       Shaun Weien
# 9981    9982  CA-2017-163566     First Class    TB-21055   Ted Butterfield
# 9982    9983  US-2016-157728  Standard Class    RC-19960        Ryan Crowe
# 9983    9984  US-2016-157728  Standard Class    RC-19960        Ryan Crowe
# 9984    9985  CA-2015-100251  Standard Class    DV-13465  Dianna Vittorini
# ...

# %%
new_df.columns
# Out:
# Index(['row_id', 'order_id', 'ship_mode', 'customer_id', 'customer_name',
#        'segment', 'country', 'city', 'state', 'postal_code', 'region',
#        'product_id', 'category', 'sub_category', 'product_name', 'sales',
#        'quantity', 'discount', 'profit', 'order_date_year', 'order_date_month',
#        'order_date_day', 'ship_date_year', 'ship_date_month', 'ship_date_day'],
#       dtype='object')

# %%
data_df=df.loc[:, ['region','product_id', 'category', 'sub_category', 'product_name']].copy()

# %%
data_df
# Out:
#      region       product_id         category sub_category  \
# 0     South  FUR-BO-10001798        Furniture    Bookcases
# 1     South  FUR-CH-10000454        Furniture       Chairs
# 2      West  OFF-LA-10000240  Office Supplies       Labels
# 3     South  FUR-TA-10000577        Furniture       Tables
# 4     South  OFF-ST-10000760  Office Supplies      Storage
# ...     ...              ...              ...          ...
# 9989  South  FUR-FU-10001889        Furniture  Furnishings
# 9990   West  FUR-FU-10000747        Furniture  Furnishings
# 9991   West  TEC-PH-10003645       Technology       Phones
# 9992   West  OFF-PA-10004041  Office Supplies        Paper
# 9993   West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            product_name
# 0                     Bush Somerset Collection Bookcase
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2     Self-Adhesive Address Labels for Typewriters b...
# ...

# %%
df=new_df.copy()
import matplotlib.pyplot as plt

# create a scatter plot of sales vs profit
plt.scatter(df['sales'], df['profit'])

# set plot title and axis labels
plt.title('Sales vs Profit')
plt.xlabel('Sales')
plt.ylabel('Profit')

# show plot
plt.show()

# %%
# group the data by category and sum the sales
sales_by_category = df.groupby('category')['sales'].sum()

# create a bar chart of sales by category
sales_by_category.plot(kind='bar')

# set plot title and axis labels
plt.title('Sales by Category')
plt.xlabel('Category')
plt.ylabel('Sales')

# show plot
plt.show()

# %%
df['country'].value_counts()
# Out:
# United States    9994
# Name: country, dtype: int64

# %%
count=df['city'].value_counts()

# %%
count
# Out:
# New York City      915
# Los Angeles        747
# Philadelphia       537
# San Francisco      510
# Seattle            428
#                   ...
# Glenview             1
# Missouri City        1
# Rochester Hills      1
# Palatine             1
# Manhattan            1
# Name: city, Length: 531, dtype: int64

# %%
# group the data by category and sum the sales
sales_by_city = df.groupby('city')['sales'].sum()
top_cities=sales_by_city.sort_values(ascending=False)[:10]
# create a bar chart of sales by category
top_cities.plot(kind='bar')

# set plot title and axis labels
plt.title('Sales by cities')
plt.xlabel('Category')
plt.ylabel('Sales')

# show plot
plt.show()
